# %% [markdown]
# ### FUTURES
#
# A future, or promise, is something that represents a pending opearion and returns straight away. One can then query their state of completion, or register callbacks to be called on successful completion or error.
#
# Examples Adapted from Fluent Python.

# %%
import time, uuid, functools
def get_thing_maker(secs, item):
    time.sleep(secs)
    return str(uuid.uuid4())+str(item)
get_thing = functools.partial(get_thing_maker, 1)
def get_many(lot):
    counter=0
    for t in lot:
        thing = get_thing(t)
        counter += 1
    return counter
def serial_main(it):
    t0 = time.time()
    count = get_many(it)
    elapsed = time.time() - t0
    msg = '\n{} things got in {:.2f}s' 
    print(msg.format(count, elapsed))

# %% [markdown]
# #### Serial sleeping

# %%
serial_main(range(20))
# Out:
# 20 things got in 20.04s

# %% [markdown]
# #### concurrent sleeping using threads

# %%
from concurrent import futures
def get_many_threaded1(it):
    workers = 10
    with futures.ThreadPoolExecutor(max_workers=workers) as executor:
        res = executor.map(get_thing, it)
    return len(list(res))
def threaded_main1(it):
    t0 = time.time()
    count = get_many_threaded1(it)
    elapsed = time.time() - t0
    msg = '\n{} things got in {:.2f}s' 
    print(msg.format(count, elapsed))

# %%
threaded_main1(range(20))
# Out:
# 20 things got in 2.00s

# %% [markdown]
# One might think that the concurrent IO (or sleeping) case is limited by the GIL, but in both cases, the GIL is yielded. Thus there is no waiting around.
#
# The GIL is harmless if code is being run in the context of python library IO or code running in properly coded C extensions like numpy.  The time.sleep() function also releases the GIL. Python threads are totally usable in I/O-bound applications.

# %% [markdown]
# ### Threads
#
# threads vs processes
#
# On linux
#
# - processes created by fork()
# - have a primary thread
# - thread is the unit of execution
# - process is a container, can have more threads
# - can be scheduled across different cores/cpus
#
# ```c
# int pid;
# int status = 0;
# /* fork returns pid of child to parent and 0 to child*/
# if (pid = fork()) {
#     /* parent code */
#     pid = wait(&status);
#     /*wait returns child pid and status*/
# } else {
#     /* child  code*/
#     exit(status);
# }
# ```
#
# - threads in a process share same address space (share it entirely)
# - thread abstraction decouples resource allocation from control
# - defines a single sequential execution stream with PC, stack, register values
# - process handles: address space, global variables, open files, child processes, pending alarms, signals and signal handlers, accounting info
# - thread handles program counter, registers, stack, and state
# - user vs kernel threads

# %%
def fib(n):
    return fib(n - 1) + fib(n - 2) if n > 1 else n

# %%
from threading import Thread
from time import sleep
from time import time


def sleepy(): #like io
    i=0
    while i < 10:
        print("{} -- {} Sleepy!".format(i, int(time())), flush=True)
        sleep(3)
        i += 1


def cpuy():
    for i in range(35):
        val = fib(i)
        print("fib({}) is {}".format(i, val))

def cpuy2():
    for i in range(35):
        val = fib(i)
        print("cpuy2 fib({}) is {}".format(i, val))
        
def main():
    # Second thread will print the hello message. Starting as a daemon means
    # the thread will not prevent the process from exiting.
    start = time()
    cpuy()
    cpuy2()
    print("serial elapsed:", time() - start)
    start=time()
    #t = Thread(target=sleepy)
    #t.start()
    t2 = Thread(target=cpuy2)
    t2.start()
    # Main thread will read and process input
    cpuy()
    print("thread elapsed:", time() - start)
if __name__ == '__main__':
    main()
# Out:
# fib(0) is 0
# fib(1) is 1
# fib(2) is 1
# fib(3) is 2
# fib(4) is 3
# fib(5) is 5
# fib(6) is 8
# fib(7) is 13
# fib(8) is 21
# fib(9) is 34
# fib(10) is 55
# fib(11) is 89
# fib(12) is 144
# fib(13) is 233
# fib(14) is 377
# fib(15) is 610
# fib(16) is 987
# fib(17) is 1597
# fib(18) is 2584
# fib(19) is 4181
# fib(20) is 6765
# fib(21) is 10946
# fib(22) is 17711
# fib(23) is 28657
# fib(24) is 46368
# fib(25) is 75025
# fib(26) is 121393
# fib(27) is 196418
# fib(28) is 317811
# fib(29) is 514229
# fib(30) is 832040
# fib(31) is 1346269
# fib(32) is 2178309
# fib(33) is 3524578
# fib(34) is 5702887
# cpuy2 fib(0) is 0
# cpuy2 fib(1) is 1
# cpuy2 fib(2) is 1
# cpuy2 fib(3) is 2
# cpuy2 fib(4) is 3
# cpuy2 fib(5) is 5
# cpuy2 fib(6) is 8
# cpuy2 fib(7) is 13
# cpuy2 fib(8) is 21
# cpuy2 fib(9) is 34
# cpuy2 fib(10) is 55
# cpuy2 fib(11) is 89
# cpuy2 fib(12) is 144
# cpuy2 fib(13) is 233
# cpuy2 fib(14) is 377
# cpuy2 fib(15) is 610
# cpuy2 fib(16) is 987
# cpuy2 fib(17) is 1597
# cpuy2 fib(18) is 2584
# cpuy2 fib(19) is 4181
# cpuy2 fib(20) is 6765
# cpuy2 fib(21) is 10946
# cpuy2 fib(22) is 17711
# cpuy2 fib(23) is 28657
# cpuy2 fib(24) is 46368
# cpuy2 fib(25) is 75025
# cpuy2 fib(26) is 121393
# cpuy2 fib(27) is 196418
# cpuy2 fib(28) is 317811
# cpuy2 fib(29) is 514229
# cpuy2 fib(30) is 832040
# cpuy2 fib(31) is 1346269
# cpuy2 fib(32) is 2178309
# cpuy2 fib(33) is 3524578
# cpuy2 fib(34) is 5702887
# serial elapsed: 18.62970805168152
# cpuy2 fib(0) is 0
# cpuy2 fib(1) is 1
# cpuy2 fib(2) is 1
# cpuy2 fib(3) is 2
# cpuy2 fib(4) is 3
# cpuy2 fib(5) is 5
# cpuy2 fib(6) is 8
# cpuy2 fib(7) is 13
# cpuy2 fib(8) is 21
# cpuy2 fib(9) is 34
# cpuy2 fib(10) is 55
# cpuy2 fib(11) is 89
# cpuy2 fib(12) is 144
# cpuy2 fib(13) is 233
# cpuy2 fib(14) is 377
# cpuy2 fib(15) is 610
# cpuy2 fib(16) is 987
# cpuy2 fib(17) is 1597
# cpuy2 fib(18) is 2584
# fib(0) is 0
# fib(1) is 1
# fib(2) is 1
# fib(3) is 2
# fib(4) is 3
# fib(5) is 5
# fib(6) is 8
# fib(7) is 13
# fib(8) is 21
# fib(9) is 34
# fib(10) is 55
# fib(11) is 89
# fib(12) is 144
# fib(13) is 233
# fib(14) is 377
# fib(15) is 610
# fib(16) is 987
# fib(17) is 1597
# fib(18) is 2584
# cpuy2 fib(19) is 4181
# fib(19) is 4181
# fib(20) is 6765
# cpuy2 fib(20) is 6765
# fib(21) is 10946
# cpuy2 fib(21) is 10946
# cpuy2 fib(22) is 17711
# fib(22) is 17711cpuy2 fib(23) is 28657
#
# cpuy2 fib(24) is 46368
# fib(23) is 28657
# cpuy2 fib(25) is 75025
# fib(24) is 46368
# cpuy2 fib(26) is 121393
# fib(25) is 75025
# fib(26) is 121393
# cpuy2 fib(27) is 196418
# fib(27) is 196418
# cpuy2 fib(28) is 317811
# fib(28) is 317811
# cpuy2 fib(29) is 514229
# fib(29) is 514229
# cpuy2 fib(30) is 832040
# fib(30) is 832040
# cpuy2 fib(31) is 1346269
# fib(31) is 1346269
# cpuy2 fib(32) is 2178309
# fib(32) is 2178309
# cpuy2 fib(33) is 3524578
# fib(33) is 3524578
# cpuy2 fib(34) is 5702887
# fib(34) is 5702887
# thread elapsed: 19.23670983314514

# %% [markdown]
# ### Processes with concurrent futures.
#
# CPU based processing wont release the gil, and is thus best done in a separate process. For illustration, we show what this looks like.

# %%
import time
def get_many_process(it, workers=None):
    if workers:
        with futures.ProcessPoolExecutor(max_workers=workers) as executor:
            res = executor.map(get_thing, it)
    else:
        with futures.ProcessPoolExecutor() as executor:
            res = executor.map(get_thing, it)
    return len(list(res))

def process_main(it, workers=None):
    t0 = time.time()
    count = get_many_process(it, workers)
    elapsed = time.time() - t0
    msg = '\n{} things got in {:.2f}s' 
    print(msg.format(count, elapsed))

# %%
process_main(range(20))
# Out:
# 20 things got in 5.06s

# %%
process_main(range(20), workers=10)
# Out:
# 20 things got in 2.11s

# %%
print(__name__)
# Out:
# __main__

# %%
import multiprocessing
start = time.time()
p=multiprocessing.Process(target=cpuy2)
p.start()
cpuy()
p.join()
print("mp elapsed:", time.time() - start)
# Out:
# fib(0) is 0
# fib(1) is 1
# fib(2) is 1
# fib(3) is 2
# fib(4) is 3
# fib(5) is 5
# fib(6) is 8
# fib(7) is 13
# fib(8) is 21
# fib(9) is 34
# fib(10) is 55
# fib(11) is 89
# fib(12) is 144
# fib(13) is 233
# fib(14) is 377
# fib(15) is 610
# fib(16) is 987
# fib(17) is 1597
# fib(18) is 2584
# fib(19) is 4181
# fib(20) is 6765
# fib(21) is 10946
# fib(22) is 17711
# fib(23) is 28657cpuy2 fib(0) is 0
# cpuy2 fib(1) is 1
# cpuy2 fib(2) is 1
# cpuy2 fib(3) is 2
# cpuy2 fib(4) is 3
# cpuy2 fib(5) is 5
# cpuy2 fib(6) is 8
# cpuy2 fib(7) is 13
# cpuy2 fib(8) is 21
# cpuy2 fib(9) is 34
# cpuy2 fib(10) is 55
# cpuy2 fib(11) is 89
# cpuy2 fib(12) is 144
# cpuy2 fib(13) is 233
# cpuy2 fib(14) is 377
# cpuy2 fib(15) is 610
# cpuy2 fib(16) is 987
# cpuy2 fib(17) is 1597
# cpuy2 fib(18) is 2584
# cpuy2 fib(19) is 4181
# cpuy2 fib(20) is 6765
# cpuy2 fib(21) is 10946
#
# fib(24) is 46368cpuy2 fib(22) is 17711
# cpuy2 fib(23) is 28657
#
# fib(25) is 75025cpuy2 fib(24) is 46368
#
# fib(26) is 121393cpuy2 fib(25) is 75025
#
# fib(27) is 196418cpuy2 fib(26) is 121393
# cpuy2 fib(27) is 196418
#
# fib(28) is 317811cpuy2 fib(28) is 317811
#
# fib(29) is 514229cpuy2 fib(29) is 514229
#
# fib(30) is 832040cpuy2 fib(30) is 832040
#
# fib(31) is 1346269cpuy2 fib(31) is 1346269
#
# fib(32) is 2178309cpuy2 fib(32) is 2178309
#
# fib(33) is 3524578cpuy2 fib(33) is 3524578
#
# fib(34) is 5702887cpuy2 fib(34) is 5702887
#
# mp elapsed: 12.47210693359375

# %%
input('>')

# %% [markdown]
# ### sockets
#
# - distinction between "client socket" and "server socket"
# - default `socket.socket(family=AF_INET, type=SOCK_STREAM, proto=0, fileno=None)`
# - server socket sits and creates client sockets
# - non-blocking sockets and the `select` system call
#
# Read: https://docs.python.org/3.5/howto/sockets.html

# %% [markdown]
# ### Writing a web page fetcher
#
# We'll eventually use the asyncio module to play with web page fetching and crawling, but lets build up to that by writing a simple fetcher. We'll start with blocking, then move to non-blocking, and finally to co-routines, and even more finally to `yield from` based co-routines.
#
# Adapted from http://aosabook.org/en/500L/a-web-crawler-with-asyncio-coroutines.html

# %% [markdown]
# #### Blocking fetch

# %%
import socket
def fetch(host, url):
    sock = socket.socket()
    sock.connect((host, 80))
    request = 'GET {} HTTP/1.0\r\nHost: {}\r\n\r\n'.format(url, host)
    sock.send(request.encode('ascii'))
    response = b''
    chunk = sock.recv(4096)
    while chunk:
        response += chunk
        chunk = sock.recv(4096)
    return response

# %%
from IPython.display import HTML, IFrame
HTML(str(fetch("www.example.com","/")))
# Out:
# b'HTTP/1.0 200 OK\r\nAccept-Ranges: bytes\r\nCache-Control: max-age=604800\r\nContent-Type: text/html\r\nDate: Sun, 03 Apr 2016 19:45:45 GMT\r\nEtag: "359670651"\r\nExpires: Sun, 10 Apr 2016 19:45:45 GMT\r\nLast-Modified: Fri, 09 Aug 2013 23:54:35 GMT\r\nServer: ECS (rhv/818F)\r\nVary: Accept-Encoding\r\nX-Cache: HIT\r\nx-ec-custom-error: 1\r\nContent-Length: 1270\r\nConnection: close\r\n\r\n<!doctype html>\n<html>\n<head>\n    <title>Example Domain</title>\n\n    <meta charset="utf-8" />\n    <meta http-equiv="Content-type" content="text/html; charset=utf-8" />\n    <meta name="viewport" content="width=device-width, initial-scale=1" />\n    <style type="text/css">\n    body {\n        background-color: #f0f0f2;\n        margin: 0;\n        padding: 0;\n        font-family: "Open Sans", "Helvetica Neue", Helvetica, Arial, sans-serif;\n        \n    }\n    div {\n        width: 600px;\n        margin: 5em auto;\n        padding: 50px;\n        background-color: #fff;\n        border-radius: 1em;\n    }\n    a:link, a:visited {\n        color: #38488f;\n        text-decoration: none;\n    }\n    @media (max-width: 700px) {\n        body {\n            background-color: #fff;\n        }\n        div {\n            width: auto;\n            margin: 0 auto;\n            border-radius: 0;\n            padding: 1em;\n        }\n    }\n    </style>    \n</head>\n\n<body>\n<div>\n    <h1>Example Domain</h1>\n    <p>This domain is established to be used for illustrative examples in documents. You may use this\n    domain in examples without prior coordination or asking for permission.</p>\n    <p><a href="http://www.iana.org/domains/example">More information...</a></p>\n</div>\n</body>\n</html>\n'

# %% [markdown]
# #### Basic non-blocking

# %%
host="www.example.com"
url="/"
request = 'GET {} HTTP/1.0\r\nHost: {}\r\n\r\n'.format(url, host)
encoded = request.encode('ascii')
sock = socket.socket()
sock.setblocking(False)
try:
    sock.connect(('xkcd.com', 80))
except BlockingIOError:
    pass
while True:
    try:
        sock.send(encoded)
        break  # Done.
    except OSError as e:
        pass

print('sent')
# Out:
# sent

# %% [markdown]
# This has only been implemented partially. Notice how the `sock.send` spins in a loop.
#
# This eats cycles. the solution is to use select/kqueue/epoll from a small number of connections to a large number of them. The basic idea behind `select` is to wait for an event to occur on a small set of non-blocking sokets.
#
# We'll use python's `DefaultSelector`, an addition from python 3.4 that automatically chooses the "best" select like implementation on your system.

# %%
from selectors import DefaultSelector, EVENT_WRITE
from time import time
selector = DefaultSelector()
host="www.example.com"
sock = socket.socket()
sock.setblocking(False)
try:
    sock.connect((host, 80))
except BlockingIOError:
    pass

def connected():
    selector.unregister(sock.fileno())
    print('connected!', flush=True)

selector.register(sock.fileno(), EVENT_WRITE, connected)
# Out:
# SelectorKey(fileobj=55, fd=55, events=2, data=<function connected at 0x1051a7c80>)

# %% [markdown]
# `connected` is the **callback** run when the connection happens.

# %%
def loop():
    start = time()
    while True:
        if time() - start > 10:
            break
        events = selector.select()
        for event_key, event_mask in events:
            callback = event_key.data
            callback()

# %% [markdown]
# Such a loop is called an "event loop". An async frameworkhas two parts: (a) such an event loop and (b) non-blocking sockets. It all runs on one thread. This is a system, it should be obvious for I/O bound problems.
#
# What have we demonstrated already? We showed how to begin an operation and execute a callback when the operation is ready. An async framework builds on the two features we have shown—non-blocking sockets and the event loop—to run concurrent operations on a single thread.
#
# Guido:
# >We have achieved "concurrency" here, but not what is traditionally called "parallelism". What asynchronous I/O is right for, is applications with many slow or sleepy connections with infrequent events.

# %%
loop() #loop will destruct after 10 secs
# Out:
# connected!

# %% [markdown]
# #### async with response reading

# %%
from selectors import DefaultSelector, EVENT_READ, EVENT_WRITE

selector = DefaultSelector()
class Fetcher:
    def __init__(self, host, url, level=0):
        self.response = b''  # Empty array of bytes.
        self.host = host
        self.url = url
        self.sock = None
        
    # Method on Fetcher class.
    def fetch(self):
        self.sock = socket.socket()
        self.sock.setblocking(False)
        try:
            self.sock.connect((self.host, 80))
        except BlockingIOError:
            pass

        # Register next callback.
        selector.register(self.sock.fileno(),
                          EVENT_WRITE,
                          self.connected)

    def connected(self, key, mask):
        print('connected!', flush=True)
        selector.unregister(key.fd)
        request = 'GET {} HTTP/1.0\r\nHost: {}\r\n\r\n'.format(self.url, self.host)
        self.sock.send(request.encode('ascii'))

        # Register the next callback.
        selector.register(key.fd,
                          EVENT_READ,
                          self.read_response)
        
    def read_response(self, key, mask):
        global stopped
        
        chunk = self.sock.recv(128)  # USUALLY 4k chunk size, here small
        if chunk:
            print("read chunk", flush=True)
            self.response += chunk
        else:
            print("all read", flush=True)
            selector.unregister(key.fd)  # Done reading.
            stopped=True
            
stopped = False

def loop():
    while not stopped:
        events = selector.select()
        for event_key, event_mask in events:
            callback = event_key.data
            callback(event_key, event_mask)
        #do fibonacci

# %%
fetcher = Fetcher('xkcd.com', '/353/')
fetcher.fetch()
loop()
# Out:
# connected!
# read chunk
# read chunk
# read chunk
# read chunk
# read chunk
# read chunk
# read chunk
# read chunk
# read chunk
# read chunk
# read chunk
# read chunk
# read chunk
# read chunk
# read chunk
# read chunk
# read chunk
# read chunk
# read chunk
# read chunk
# read chunk
# read chunk
# read chunk
# read chunk
# read chunk
# read chunk
# read chunk
# read chunk
# read chunk
# read chunk
# read chunk
# read chunk
# read chunk
# read chunk
# read chunk
# read chunk
# read chunk
# read chunk
# read chunk
# read chunk
# read chunk
# read chunk
# read chunk
# read chunk
# read chunk
# read chunk
# read chunk
# read chunk
# read chunk
# read chunk
# read chunk
# read chunk
# read chunk
# read chunk
# read chunk
# read chunk
# read chunk
# read chunk
# all read

# %% [markdown]
# You can see how the control-flow is chained together by having the connected callback do the resposing. Beyond a 2-3 ladder, this gets confusing and onerous (see some node.js code). As compared to a blocking program, where the continuation of the program is stored and adressed via the instruction pointer in a sequential fashiom, here the cintinuation is stored by registering the callbacks.'
#
# Since the current frame is popped out of the stack, exceptions have a hard time figuring the origin This is called stack-ripping.
#
# So, even apart from the long debate about the relative efficiencies of multithreading and async, there is this other debate regarding which is more error-prone: threads are susceptible to data races if you make a mistake synchronizing them, but callbacks are stubborn to debug due to stack ripping. And within a bit, we get callback soup.
#
# https://thesynchronousblog.wordpress.com/tag/stack-ripping/
#
# Threads seem to offer a more natural way of programming as the programmer with all state in thread’s single stack.

# %% [markdown]
# So why not use them. As we said last time: synchronization and overhead.
#
# But we can do better with Coroutines!
#
# Guido:
# >We entice you with a promise. It is possible to write asynchronous code that combines the efficiency of callbacks with the classic good looks of multithreaded programming. This combination is achieved with a pattern called "coroutines". Using Python 3.4's standard asyncio library, and a package called "aiohttp", fetching a URL in a coroutine is very direct7:
#
#     @asyncio.coroutine
#     def fetch(self, url):
#         response = yield from self.session.get(url)
#         body = yield from response.read()
#
# In 3.5 its even more clear:
#
# async def fetch(self, url):
#         response = await self.session.get(url)
#         body = await response.read()

# %% [markdown]
# ### Back to the Future with co-routines

# %%
from selectors import DefaultSelector, EVENT_READ, EVENT_WRITE
import socket
selector = DefaultSelector()

# %% [markdown]
# The future, as you might expect is something with callbacks...

# %%
class MyFuture:
    def __init__(self):
        self.result = None
        self._callbacks = []

    def add_done_callback(self, fn):
        self._callbacks.append(fn)

    def set_result(self, result):
        self.result = result
        for fn in self._callbacks:
            fn(self)

# %% [markdown]
# We need a "main" to yield to.

# %%
class Fetcher:
    
    def __init__(self, url, host):
        self.url = url
        self.host = host
        self.response = b''  # Empty array of bytes.

        
    def fetch(self):
        global stopped
        sock = socket.socket()

        sock.setblocking(False)
        try:
            sock.connect((self.host, 80))
        except BlockingIOError:
            pass

        f = MyFuture()

        #resolves the future by setting a result on it
        def on_connected():
            print('on connected cb ran', flush=True)
            f.set_result(None)
        
        
        
        selector.register(sock.fileno(),
                          EVENT_WRITE,
                          on_connected)
        print("about to yield connection future", flush=True)
        yield f#this makes it look like fetch has returned the "future"
        #bit we have not lost the state (or have to have carried it in obj)
        #a send in will continue us here
        print('we were connected! now back in gen', flush=True)
        selector.unregister(sock.fileno())
        request = 'GET {} HTTP/1.0\r\nHost: {}\r\n\r\n'.format(self.url, self.host)
        sock.send(request.encode('ascii'))
        while True:
            print("in loop")
            #now create a new future for the data-recieving call
            f = MyFuture()
            def on_response():
                chunky = sock.recv(4096)  # 4k chunk size.
                f.set_result(chunky)
            selector.register(sock.fileno(),
                              EVENT_READ,
                              on_response)
            #now to restart the gen, we will from the main
            #throw the data right back in
            chunk = yield f
            selector.unregister(sock.fileno())
            if chunk:
                print("len(chunk)",len(chunk))
                self.response += chunk
            else:
                print("all read")
                stopped= True
                break

# %%
#But when the future resolves, what resumes the generator? We need a coroutine driver. Let us call it "task":
#(this is our main)
class Task:
    def __init__(self, coro):
        self.coro = coro
        f = MyFuture()
        print(">>sending none to initial future",f)
        f.set_result(None)
        print("...stepping")
        self.step(f)
        print(">>>after priming")

    def step(self, future):
        try:
            print("sending", type(future.result))
            next_future = self.coro.send(future.result)
            print('got next future', next_future)

        except StopIteration:
            print("si")
            return None
        next_future.add_done_callback(self.step)

# %%
stopped=False
def loop():
    while not stopped:
        events = selector.select()
        for event_key, event_mask in events:
            callback = event_key.data
            callback()

# %%
fetcher = Fetcher('/353/', 'xkcd.com')
Task(fetcher.fetch())
stopped=False
loop()
# Out:
# >>sending none to initial future <__main__.MyFuture object at 0x1051be748>
# ...stepping
# sending <class 'NoneType'>
# about to yield connection future
# got next future <__main__.MyFuture object at 0x1051be7b8>
# >>>after priming
# on connected cb ran
# sending <class 'NoneType'>
# we were connected! now back in gen
# in loop
# got next future <__main__.MyFuture object at 0x1051be748>
# sending <class 'bytes'>
# len(chunk) 4096
# in loop
# got next future <__main__.MyFuture object at 0x1051be400>
# sending <class 'bytes'>
# len(chunk) 3279
# in loop
# got next future <__main__.MyFuture object at 0x1051be470>
# sending <class 'bytes'>
# all read
# si

# %% [markdown]
# #### Refactoring using generators

# %%
#But when the future resolves, what resumes the generator? We need a coroutine driver. Let us call it "task":
#(this is our main)
class Task:
    def __init__(self, coro):
        self.coro = coro
        f = MyFuture()
        print(">>sending none to initial future",f)
        f.set_result(None)
        print("...stepping")
        self.step(f)
        print(">>>after priming")

    def step(self, future):
        try:
            print("sending", type(future.result))
            next_future = self.coro.send(future.result)
            print('got next future', next_future)

        except StopIteration:
            print("si")
            return None
        next_future.add_done_callback(self.step)

# %%
def read(sock):
    f = MyFuture()

    def on_readable():
        f.set_result(sock.recv(4096))

    selector.register(sock.fileno(), EVENT_READ, on_readable)
    chunk = yield f  # Read one chunk.
    selector.unregister(sock.fileno())
    return chunk

# %%
def read_all(sock):
    global stopped
    response = []
    # Read whole response.
    chunk = yield from read(sock)
    while chunk:
        response.append(chunk)
        chunk = yield from read(sock)
    stopped=True
    return b''.join(response)

# %% [markdown]
# >If you squint and make the yield from statements disappear it looks like  conventional functions doing blocking I/O. But in fact, read and read_all are coroutines. Yielding from read pauses read_all until the I/O completes. While read_all is paused, asyncio's event loop does other work and awaits other I/O events; read_all is resumed with the result of read on the next loop tick once its event is ready.

# %%
class Fetcher:
    
    def __init__(self, url, host):
        self.url = url
        self.host = host
        self.response = b''  # Empty array of bytes.

        
    def fetch(self):
        global stopped
        sock = socket.socket()

        sock.setblocking(False)
        try:
            sock.connect((host, 80))
        except BlockingIOError:
            pass

        f = MyFuture()

        def on_connected():
            print('on connected cb ran')
            f.set_result(None)
        
        
        
        selector.register(sock.fileno(),
                          EVENT_WRITE,
                          on_connected)
        print("about to yield connection future")
        yield f
        print('connected!')
        selector.unregister(sock.fileno())
        request = 'GET {} HTTP/1.0\r\nHost: xkcd.com\r\n\r\n'.format(self.url)
        sock.send(request.encode('ascii'))
        yield from read_all(sock)

# %%
fetcher = Fetcher('/353/', 'xkcd.com')
Task(fetcher.fetch())
stopped = False
loop()
# Out:
# >>sending none to initial future <__main__.MyFuture object at 0x1051c5518>
# ...stepping
# sending <class 'NoneType'>
# about to yield connection future
# got next future <__main__.MyFuture object at 0x1051c55f8>
# >>>after priming
# on connected cb ran
# sending <class 'NoneType'>
# connected!
# got next future <__main__.MyFuture object at 0x1051c5588>
# sending <class 'bytes'>
# got next future <__main__.MyFuture object at 0x1051c54e0>
# sending <class 'bytes'>
# si

# %% [markdown]
# ![](http://aosabook.org/en/500L/crawler-images/yield-from.png)
#
# There is one yield left amongst the yield froms. For consistency, this can be fixed...it also lets us change implementations under the hood..

# %%
def read(sock):
    f = MyFuture()

    def on_readable():
        f.set_result(sock.recv(4096))

    selector.register(sock.fileno(), EVENT_READ, on_readable)
    chunk = yield from f  # Read one chunk.
    selector.unregister(sock.fileno())
    return chunk

# %%
class MyFuture:
    def __init__(self):
        self.result = None
        self._callbacks = []

    def add_done_callback(self, fn):
        self._callbacks.append(fn)

    def set_result(self, result):
        self.result = result
        print("cblist", self._callbacks)
        for fn in self._callbacks:
            fn(self)
            
    def __iter__(self):
        yield self
        return self.result

# %%
class Fetcher:
    
    def __init__(self, url, host):
        self.url = url
        self.host = host
        self.response = b''  # Empty array of bytes.
        self.sock = None

        
    def fetch(self):
        global stopped
        self.sock = socket.socket()
        self.sock.setblocking(False)
        try:
            self.sock.connect((self.host, 80))
        except BlockingIOError:
            pass

        f = MyFuture()

        def on_connected():
            print('on connected cb ran')
            f.set_result(None)
        
        
        
        selector.register(sock.fileno(),
                          EVENT_WRITE,
                          on_connected)
        print("about to yield connection future")
        yield from f
        print('connected!')
        selector.unregister(sock.fileno())
        request = 'GET {} HTTP/1.0\r\nHost: xkcd.com\r\n\r\n'.format(self.url)
        sock.send(request.encode('ascii'))
        yield from read_all(sock)

# %%
fetcher = Fetcher('/353/','xkcd.com')
Task(fetcher.fetch())
stopped = False
loop()
# Out:
# >>sending none to initial future <__main__.MyFuture object at 0x1051aeb38>
# cblist []
# ...stepping
# sending <class 'NoneType'>
# about to yield connection future
# got next future <__main__.MyFuture object at 0x1051ae160>
# >>>after priming
# on connected cb ran
# cblist [<bound method Task.step of <__main__.Task object at 0x1051ae240>>]
# sending <class 'NoneType'>
# connected!
# got next future <__main__.MyFuture object at 0x1051ae9b0>
# cblist [<bound method Task.step of <__main__.Task object at 0x1051ae240>>]
# sending <class 'bytes'>
# got next future <__main__.MyFuture object at 0x1051ae0f0>
# cblist [<bound method Task.step of <__main__.Task object at 0x1051ae240>>]
# sending <class 'bytes'>
# got next future <__main__.MyFuture object at 0x1051aeb38>
# cblist [<bound method Task.step of <__main__.Task object at 0x1051ae240>>]
# sending <class 'bytes'>
# si

# %% [markdown]
# ## Lab
#
# Implement a URL fetcher using Beautiful Soup in the callback version. We will implement a similar one using coroutines on wednesday.
#
# The implimentation will extend the read_response method by parsing for URL's using `bs4` . Start by creating globals:
# ```
# urls_todo = set(['/'])
# seen_urls = set(['/'])
# ```
#
# then:
#
# ```
# links = self.parse_links()#write this
# ```
# (using self.response)
#
# Then use the set `difference` method  to add new links to `urls_todo` and recursively set up a `Fetcher` instance.
#
# Now update the `seen_urls` and `urls_todo` thus:
# ```
# seen_urls.update(links)
# urls_todo.remove(self.url)
# if not urls_todo:
#     stopped = True
# ```

# %%
from bs4 import BeautifulSoup

# We adapted the Fetcher class from above
class URLFetcher:
    
    def __init__(self, url, host):
        self.url = url
        self.host = host
        self.response = b''  # Empty array of bytes.
        self.sock = None # Attribute initialized in fetch function
        
    # Method on Fetcher class.
    def fetch(self):
        self.sock = socket.socket()
        self.sock.setblocking(False)
        try:
            self.sock.connect((self.host, 80))
        except BlockingIOError:
            pass

        # Register next callback.
        selector.register(self.sock.fileno(),
                          EVENT_WRITE,
                          self.connected)

    def connected(self, key, mask):
        print('connected to url {} with host {}'.format(self.url, self.host), flush=True)
        selector.unregister(key.fd)
        request = 'GET {} HTTP/1.0\r\nHost: {}\r\n\r\n'.format(self.url, self.host)
        self.sock.send(request.encode('ascii'))

        # Register the next callback.
        selector.register(key.fd,
                          EVENT_READ,
                          self.read_response)
        
    # Adapted function
    def read_response(self, key, mask):
        global stopped
        global seen_urls
        global urls_todo
        
        chunk = self.sock.recv(128)  # USUALLY 4k chunk size, here small
        if chunk:
            self.response += chunk
        else:

            # Remove url
            if self.url in urls_todo:
                urls_todo.remove(self.url)
            
            selector.unregister(key.fd)  # Done reading.
                
            # Using the set difference method to add new
            # links to urls_todo and recursively set up a
            # Fetcher instance.
            links = self.parse_links()
            
            for link in links.difference(seen_urls):
                urls_todo.add(link)
                URLFetcher(link, self.host).fetch()
            
            seen_urls.update(links)
            if self.url in urls_todo:
                urls_todo.remove(self.url)

            # Stop criterion
            if not urls_todo:
                stopped = True
    # Adapted function to fetch links from a new page        
    def parse_links(self):
        soup = BeautifulSoup(self.response, 'html.parser')
        links = soup.find_all('a', href=True)
        # We restrict to the local link
        return set([l['href'] for l in links if l['href'][0]=='/'])
    

def loop():
    while not stopped:
        events = selector.select()
        for event_key, event_mask in events:
            callback = event_key.data
            callback(event_key, event_mask)

# %%
selector = DefaultSelector()
stopped = False

urls_todo = set(['/'])
seen_urls = set(['/'])

fetcher = URLFetcher('/', 'xkcd.com')
fetcher.fetch()
loop()
# Out:
# connected to url / with host xkcd.com
# connected to url /license.html with host xkcd.com
# connected to url /archive with host xkcd.com
# connected to url /about with host xkcd.com
# connected to url //c.xkcd.com/random/comic/ with host xkcd.com
# connected to url /1/ with host xkcd.com
# connected to url /rss.xml with host xkcd.com
# connected to url /1661/ with host xkcd.com
# connected to url /atom.xml with host xkcd.com
# connected to url /2/ with host xkcd.com
# connected to url /1660/ with host xkcd.com
# connected to url /1662/ with host xkcd.com
# connected to url /3/ with host xkcd.com
# connected to url /1659/ with host xkcd.com
# connected to url /4/ with host xkcd.com
# connected to url /1658/ with host xkcd.com
# connected to url /5/ with host xkcd.com
# connected to url /6/ with host xkcd.com
# connected to url /1657/ with host xkcd.com
# connected to url /7/ with host xkcd.com
# connected to url /1656/ with host xkcd.com
# connected to url /8/ with host xkcd.com
# connected to url /1655/ with host xkcd.com
# connected to url /9/ with host xkcd.com
# connected to url /1654/ with host xkcd.com
# connected to url /10/ with host xkcd.com
# connected to url /1653/ with host xkcd.com
# connected to url /11/ with host xkcd.com
# connected to url /1652/ with host xkcd.com
# connected to url /12/ with host xkcd.com
# connected to url /1651/ with host xkcd.com
# connected to url /13/ with host xkcd.com
# connected to url /1650/ with host xkcd.com
# connected to url /14/ with host xkcd.com
# connected to url /1649/ with host xkcd.com
# connected to url /15/ with host xkcd.com
# connected to url /1648/ with host xkcd.com
# connected to url /16/ with host xkcd.com
# connected to url /1647/ with host xkcd.com
# connected to url /1646/ with host xkcd.com
# connected to url /17/ with host xkcd.com
# connected to url /1645/ with host xkcd.com
# connected to url /18/ with host xkcd.com
# connected to url /1644/ with host xkcd.com
# connected to url /19/ with host xkcd.com
# connected to url /1643/ with host xkcd.com
# connected to url /20/ with host xkcd.com
# connected to url /1642/ with host xkcd.com
# connected to url /21/ with host xkcd.com
# connected to url /1641/ with host xkcd.com
# connected to url /1640/ with host xkcd.com
# connected to url /22/ with host xkcd.com
# connected to url /1639/ with host xkcd.com
# connected to url /23/ with host xkcd.com
# connected to url /1638/ with host xkcd.com
# connected to url /24/ with host xkcd.com
# connected to url /1637/ with host xkcd.com
# connected to url /25/ with host xkcd.com
# connected to url /1636/ with host xkcd.com
# connected to url /26/ with host xkcd.com
# connected to url /1635/ with host xkcd.com
# connected to url /27/ with host xkcd.com
# connected to url /28/ with host xkcd.com
# connected to url /1634/ with host xkcd.com
# connected to url /29/ with host xkcd.com
# connected to url /1633/ with host xkcd.com
# connected to url /30/ with host xkcd.com
# connected to url /1632/ with host xkcd.com
# connected to url /31/ with host xkcd.com
# connected to url /1631/ with host xkcd.com
# connected to url /32/ with host xkcd.com
# connected to url /1630/ with host xkcd.com
# connected to url /33/ with host xkcd.com
# connected to url /1629/ with host xkcd.com
# connected to url /34/ with host xkcd.com
# connected to url /1628/ with host xkcd.com
# connected to url /35/ with host xkcd.com
# connected to url /1627/ with host xkcd.com
# connected to url /36/ with host xkcd.com
# connected to url /1626/ with host xkcd.com
# connected to url /37/ with host xkcd.com
# connected to url /1625/ with host xkcd.com
# connected to url /38/ with host xkcd.com
# connected to url /39/ with host xkcd.com
# connected to url /1624/ with host xkcd.com
# connected to url /40/ with host xkcd.com
# connected to url /1623/ with host xkcd.com
# connected to url /1622/ with host xkcd.com
# connected to url /41/ with host xkcd.com
# connected to url /1621/ with host xkcd.com
# connected to url /42/ with host xkcd.com
# connected to url /1620/ with host xkcd.com
# connected to url /43/ with host xkcd.com
# connected to url /44/ with host xkcd.com
# connected to url /1619/ with host xkcd.com
# connected to url /45/ with host xkcd.com
# connected to url /1618/ with host xkcd.com
# connected to url /46/ with host xkcd.com
# connected to url /1617/ with host xkcd.com
# connected to url /47/ with host xkcd.com
# connected to url /1616/ with host xkcd.com
# connected to url /48/ with host xkcd.com
# connected to url /1615/ with host xkcd.com
# connected to url /49/ with host xkcd.com
# connected to url /1614/ with host xkcd.com
# connected to url /50/ with host xkcd.com
# connected to url /1613/ with host xkcd.com
# connected to url /51/ with host xkcd.com
# connected to url /1612/ with host xkcd.com
# connected to url /52/ with host xkcd.com
# connected to url /1611/ with host xkcd.com
# connected to url /53/ with host xkcd.com
# connected to url /1610/ with host xkcd.com
# connected to url /54/ with host xkcd.com
# connected to url /1609/ with host xkcd.com
# connected to url /55/ with host xkcd.com
# connected to url /1608/ with host xkcd.com
# connected to url /56/ with host xkcd.com
# connected to url /1607/ with host xkcd.com
# connected to url /57/ with host xkcd.com
# connected to url /1606/ with host xkcd.com
# connected to url /58/ with host xkcd.com
# connected to url /1605/ with host xkcd.com
# connected to url /59/ with host xkcd.com
# connected to url /1604/ with host xkcd.com
# connected to url /60/ with host xkcd.com
# connected to url /1603/ with host xkcd.com
# connected to url /61/ with host xkcd.com
# connected to url /1602/ with host xkcd.com
# connected to url /62/ with host xkcd.com
# connected to url /1601/ with host xkcd.com
# connected to url /63/ with host xkcd.com
# connected to url /1600/ with host xkcd.com
# connected to url /64/ with host xkcd.com
# connected to url /1599/ with host xkcd.com
# connected to url /65/ with host xkcd.com
# connected to url /66/ with host xkcd.com
# connected to url /1598/ with host xkcd.com
# connected to url /67/ with host xkcd.com
# connected to url /1597/ with host xkcd.com
# connected to url /68/ with host xkcd.com
# connected to url /1596/ with host xkcd.com
# connected to url /69/ with host xkcd.com
# connected to url /1595/ with host xkcd.com
# connected to url /70/ with host xkcd.com
# connected to url /1594/ with host xkcd.com
# connected to url /71/ with host xkcd.com
# connected to url /72/ with host xkcd.com
# connected to url /1593/ with host xkcd.com
# connected to url /1592/ with host xkcd.com
# connected to url /73/ with host xkcd.com
# connected to url /1591/ with host xkcd.com
# connected to url /74/ with host xkcd.com
# connected to url /1590/ with host xkcd.com
# connected to url /75/ with host xkcd.com
# connected to url /1589/ with host xkcd.com
# connected to url /76/ with host xkcd.com
# connected to url /1588/ with host xkcd.com
# connected to url /77/ with host xkcd.com
# connected to url /1587/ with host xkcd.com
# connected to url /78/ with host xkcd.com
# connected to url /79/ with host xkcd.com
# connected to url /1586/ with host xkcd.com
# connected to url /80/ with host xkcd.com
# connected to url /1585/ with host xkcd.com
# connected to url /81/ with host xkcd.com
# connected to url /1584/ with host xkcd.com
# connected to url /82/ with host xkcd.com
# connected to url /1583/ with host xkcd.com
# connected to url /83/ with host xkcd.com
# connected to url /1582/ with host xkcd.com
# connected to url /84/ with host xkcd.com
# connected to url /1581/ with host xkcd.com
# connected to url /85/ with host xkcd.com
# connected to url /1580/ with host xkcd.com
# connected to url /86/ with host xkcd.com
# connected to url /1579/ with host xkcd.com
# connected to url /87/ with host xkcd.com
# connected to url /1578/ with host xkcd.com
# connected to url /88/ with host xkcd.com
# connected to url /1577/ with host xkcd.com
# connected to url /89/ with host xkcd.com
# connected to url /1576/ with host xkcd.com
# connected to url /90/ with host xkcd.com
# connected to url /1575/ with host xkcd.com
# connected to url /1574/ with host xkcd.com
# connected to url /91/ with host xkcd.com
# connected to url /1573/ with host xkcd.com
# connected to url /92/ with host xkcd.com
# connected to url /1572/ with host xkcd.com
# connected to url /93/ with host xkcd.com
# connected to url /1571/ with host xkcd.com
# connected to url /94/ with host xkcd.com
# connected to url /1570/ with host xkcd.com
# connected to url /95/ with host xkcd.com
# connected to url /1569/ with host xkcd.com
# connected to url /96/ with host xkcd.com
# connected to url /1568/ with host xkcd.com
# connected to url /97/ with host xkcd.com
# connected to url /1567/ with host xkcd.com
# connected to url /98/ with host xkcd.com
# connected to url /1566/ with host xkcd.com
# connected to url /99/ with host xkcd.com
# connected to url /1565/ with host xkcd.com
# connected to url /100/ with host xkcd.com
# connected to url /1564/ with host xkcd.com
# connected to url /101/ with host xkcd.com
# connected to url /1563/ with host xkcd.com
# connected to url /102/ with host xkcd.com
# connected to url /1562/ with host xkcd.com
# connected to url /103/ with host xkcd.com
# connected to url /1561/ with host xkcd.com
# connected to url /104/ with host xkcd.com
# connected to url /1560/ with host xkcd.com
# connected to url /105/ with host xkcd.com
# connected to url /1559/ with host xkcd.com
# connected to url /106/ with host xkcd.com
# connected to url /1558/ with host xkcd.com
# connected to url /107/ with host xkcd.com
# connected to url /1557/ with host xkcd.com
# connected to url /108/ with host xkcd.com
# connected to url /1556/ with host xkcd.com
# connected to url /109/ with host xkcd.com
# connected to url /1555/ with host xkcd.com
# connected to url /110/ with host xkcd.com
# connected to url /1554/ with host xkcd.com
# connected to url /111/ with host xkcd.com
# connected to url /1553/ with host xkcd.com
# connected to url /112/ with host xkcd.com
# connected to url /1552/ with host xkcd.com
# connected to url /113/ with host xkcd.com
# connected to url /1551/ with host xkcd.com
# connected to url /114/ with host xkcd.com
# connected to url /1550/ with host xkcd.com
# connected to url /115/ with host xkcd.com
# connected to url /1549/ with host xkcd.com
# connected to url /116/ with host xkcd.com
# connected to url /1548/ with host xkcd.com
# connected to url /117/ with host xkcd.com
# connected to url /1547/ with host xkcd.com
# connected to url /118/ with host xkcd.com
# connected to url /1546/ with host xkcd.com
# connected to url /119/ with host xkcd.com
# connected to url /1545/ with host xkcd.com
# connected to url /120/ with host xkcd.com
# connected to url /1544/ with host xkcd.com
# connected to url /121/ with host xkcd.com
# connected to url /1543/ with host xkcd.com
# connected to url /1542/ with host xkcd.com
# connected to url /122/ with host xkcd.com
# connected to url /1541/ with host xkcd.com
# connected to url /123/ with host xkcd.com
# connected to url /1540/ with host xkcd.com
# connected to url /124/ with host xkcd.com
# connected to url /1539/ with host xkcd.com
# connected to url /125/ with host xkcd.com
# connected to url /126/ with host xkcd.com
# connected to url /1538/ with host xkcd.com
# connected to url /127/ with host xkcd.com
# connected to url /1537/ with host xkcd.com
# connected to url /128/ with host xkcd.com
# connected to url /1536/ with host xkcd.com
# connected to url /129/ with host xkcd.com
# connected to url /1535/ with host xkcd.com
# connected to url /130/ with host xkcd.com
# connected to url /1534/ with host xkcd.com
# connected to url /131/ with host xkcd.com
# connected to url /1533/ with host xkcd.com
# connected to url /132/ with host xkcd.com
# connected to url /1532/ with host xkcd.com
# connected to url /133/ with host xkcd.com
# connected to url /1531/ with host xkcd.com
# connected to url /1530/ with host xkcd.com
# connected to url /134/ with host xkcd.com
# connected to url /1529/ with host xkcd.com
# connected to url /135/ with host xkcd.com
# connected to url /1528/ with host xkcd.com
# connected to url /136/ with host xkcd.com
# connected to url /137/ with host xkcd.com
# connected to url /1527/ with host xkcd.com
# connected to url /138/ with host xkcd.com
# connected to url /1526/ with host xkcd.com
# connected to url /1525/ with host xkcd.com
# connected to url /139/ with host xkcd.com
# connected to url /1524/ with host xkcd.com
# connected to url /140/ with host xkcd.com
# connected to url /1523/ with host xkcd.com
# connected to url /141/ with host xkcd.com
# connected to url /1522/ with host xkcd.com
# connected to url /142/ with host xkcd.com
# connected to url /1521/ with host xkcd.com
# connected to url /143/ with host xkcd.com
# connected to url /1520/ with host xkcd.com
# connected to url /144/ with host xkcd.com
# connected to url /1519/ with host xkcd.com
# connected to url /145/ with host xkcd.com
# connected to url /1518/ with host xkcd.com
# connected to url /146/ with host xkcd.com
# connected to url /1517/ with host xkcd.com
# connected to url /147/ with host xkcd.com
# connected to url /1516/ with host xkcd.com
# connected to url /148/ with host xkcd.com
# connected to url /1515/ with host xkcd.com
# connected to url /149/ with host xkcd.com
# connected to url /1514/ with host xkcd.com
# connected to url /150/ with host xkcd.com
# connected to url /1513/ with host xkcd.com
# connected to url /151/ with host xkcd.com
# connected to url /1512/ with host xkcd.com
# connected to url /152/ with host xkcd.com
# connected to url /1511/ with host xkcd.com
# connected to url /153/ with host xkcd.com
# connected to url /1510/ with host xkcd.com
# connected to url /154/ with host xkcd.com
# connected to url /1509/ with host xkcd.com
# connected to url /155/ with host xkcd.com
# connected to url /1508/ with host xkcd.com
# connected to url /156/ with host xkcd.com
# connected to url /1507/ with host xkcd.com
# connected to url /157/ with host xkcd.com
# connected to url /1506/ with host xkcd.com
# connected to url /158/ with host xkcd.com
# connected to url /1505/ with host xkcd.com
# connected to url //xkcd.com/1506/ with host xkcd.com
# connected to url /159/ with host xkcd.com
# connected to url /1504/ with host xkcd.com
# connected to url /160/ with host xkcd.com
# connected to url /1503/ with host xkcd.com
# connected to url /161/ with host xkcd.com
# connected to url /1502/ with host xkcd.com
# connected to url /162/ with host xkcd.com
# connected to url /1501/ with host xkcd.com
# connected to url /163/ with host xkcd.com
# connected to url /1500/ with host xkcd.com
# connected to url /164/ with host xkcd.com
# connected to url /1499/ with host xkcd.com
# connected to url /165/ with host xkcd.com
# connected to url /1498/ with host xkcd.com
# connected to url /166/ with host xkcd.com
# connected to url /1497/ with host xkcd.com
# connected to url /167/ with host xkcd.com
# connected to url /1496/ with host xkcd.com
# connected to url /168/ with host xkcd.com
# connected to url /1495/ with host xkcd.com
# connected to url /169/ with host xkcd.com
# connected to url /1494/ with host xkcd.com
# connected to url /170/ with host xkcd.com
# connected to url /1493/ with host xkcd.com
# connected to url /171/ with host xkcd.com
# connected to url /1492/ with host xkcd.com
# connected to url /172/ with host xkcd.com
# connected to url /1491/ with host xkcd.com
# connected to url /173/ with host xkcd.com
# connected to url /174/ with host xkcd.com
# connected to url /1490/ with host xkcd.com
# connected to url /1489/ with host xkcd.com
# connected to url /175/ with host xkcd.com
# connected to url /1488/ with host xkcd.com
# connected to url /176/ with host xkcd.com
# connected to url /1487/ with host xkcd.com
# connected to url /177/ with host xkcd.com
# connected to url /1486/ with host xkcd.com
# connected to url /178/ with host xkcd.com
# connected to url /1485/ with host xkcd.com
# connected to url /179/ with host xkcd.com
# connected to url /1484/ with host xkcd.com
# connected to url /1483/ with host xkcd.com
# connected to url /180/ with host xkcd.com
# connected to url /1482/ with host xkcd.com
# connected to url /181/ with host xkcd.com
# connected to url /1481/ with host xkcd.com
# connected to url /182/ with host xkcd.com
# connected to url /1480/ with host xkcd.com
# connected to url /1479/ with host xkcd.com
# connected to url /183/ with host xkcd.com
# connected to url /1478/ with host xkcd.com
# connected to url /184/ with host xkcd.com
# connected to url /1477/ with host xkcd.com
# connected to url /185/ with host xkcd.com
# connected to url /1476/ with host xkcd.com
# connected to url /186/ with host xkcd.com
# connected to url /1475/ with host xkcd.com
# connected to url /187/ with host xkcd.com
# connected to url /1474/ with host xkcd.com
# connected to url /188/ with host xkcd.com
# connected to url /189/ with host xkcd.com
# connected to url /1473/ with host xkcd.com
# connected to url /190/ with host xkcd.com
# connected to url /1472/ with host xkcd.com
# connected to url /191/ with host xkcd.com
# connected to url /1471/ with host xkcd.com
# connected to url /192/ with host xkcd.com
# connected to url /1470/ with host xkcd.com
# connected to url /193/ with host xkcd.com
# connected to url /1469/ with host xkcd.com
# connected to url /1468/ with host xkcd.com
# connected to url /194/ with host xkcd.com
# connected to url /1467/ with host xkcd.com
# connected to url /195/ with host xkcd.com
# connected to url /1466/ with host xkcd.com
# connected to url /196/ with host xkcd.com
# connected to url /1465/ with host xkcd.com
# connected to url /197/ with host xkcd.com
# connected to url /1464/ with host xkcd.com
# connected to url /198/ with host xkcd.com
# connected to url /1463/ with host xkcd.com
# connected to url /199/ with host xkcd.com
# connected to url /200/ with host xkcd.com
# connected to url /201/ with host xkcd.com
# connected to url /202/ with host xkcd.com
# connected to url /1462/ with host xkcd.com
# connected to url /203/ with host xkcd.com
# connected to url /204/ with host xkcd.com
# connected to url /1461/ with host xkcd.com
# connected to url /205/ with host xkcd.com
# connected to url /206/ with host xkcd.com
# connected to url /207/ with host xkcd.com
# connected to url /1460/ with host xkcd.com
# connected to url /208/ with host xkcd.com
# connected to url /209/ with host xkcd.com
# connected to url /210/ with host xkcd.com
# connected to url /1459/ with host xkcd.com
# connected to url /211/ with host xkcd.com
# connected to url /212/ with host xkcd.com
# connected to url /213/ with host xkcd.com
# connected to url /1458/ with host xkcd.com
# connected to url /214/ with host xkcd.com
# connected to url /1457/ with host xkcd.com
# connected to url /1456/ with host xkcd.com
# connected to url /215/ with host xkcd.com
# connected to url /1455/ with host xkcd.com
# connected to url /216/ with host xkcd.com
# connected to url /1454/ with host xkcd.com
# connected to url /217/ with host xkcd.com
# connected to url /1453/ with host xkcd.com
# connected to url /1452/ with host xkcd.com
# connected to url /218/ with host xkcd.com
# connected to url /1451/ with host xkcd.com
# connected to url /1450/ with host xkcd.com
# connected to url /1449/ with host xkcd.com
# connected to url /219/ with host xkcd.com
# connected to url /1448/ with host xkcd.com
# connected to url /1447/ with host xkcd.com
# connected to url /220/ with host xkcd.com
# connected to url /221/ with host xkcd.com
# connected to url /1446/ with host xkcd.com
# connected to url /222/ with host xkcd.com
# connected to url /1445/ with host xkcd.com
# connected to url /223/ with host xkcd.com
# connected to url /1444/ with host xkcd.com
# connected to url /224/ with host xkcd.com
# connected to url /1443/ with host xkcd.com
# connected to url /225/ with host xkcd.com
# connected to url /1442/ with host xkcd.com
# connected to url /226/ with host xkcd.com
# connected to url /1441/ with host xkcd.com
# connected to url /227/ with host xkcd.com
# connected to url /1440/ with host xkcd.com
# connected to url /228/ with host xkcd.com
# connected to url /1439/ with host xkcd.com
# connected to url /229/ with host xkcd.com
# connected to url /230/ with host xkcd.com
# connected to url /1438/ with host xkcd.com
# connected to url /231/ with host xkcd.com
# connected to url /1437/ with host xkcd.com
# connected to url /1436/ with host xkcd.com
# connected to url /232/ with host xkcd.com
# connected to url /1435/ with host xkcd.com
# connected to url /233/ with host xkcd.com
# connected to url /1434/ with host xkcd.com
# connected to url /234/ with host xkcd.com
# connected to url /1433/ with host xkcd.com
# connected to url /235/ with host xkcd.com
# connected to url /1432/ with host xkcd.com
# connected to url /1431/ with host xkcd.com
# connected to url /236/ with host xkcd.com
# connected to url /1430/ with host xkcd.com
# connected to url /237/ with host xkcd.com
# connected to url /1429/ with host xkcd.com
# connected to url /238/ with host xkcd.com
# connected to url /239/ with host xkcd.com
# connected to url /1428/ with host xkcd.com
# connected to url /240/ with host xkcd.com
# connected to url /1427/ with host xkcd.com
# connected to url /241/ with host xkcd.com
# connected to url /1426/ with host xkcd.com
# connected to url /242/ with host xkcd.com
# connected to url /1425/ with host xkcd.com
# connected to url /243/ with host xkcd.com
# connected to url /1424/ with host xkcd.com
# connected to url /244/ with host xkcd.com
# connected to url /1423/ with host xkcd.com
# connected to url /245/ with host xkcd.com
# connected to url /1422/ with host xkcd.com
# connected to url /246/ with host xkcd.com
# connected to url /247/ with host xkcd.com
# connected to url /1421/ with host xkcd.com
# connected to url /248/ with host xkcd.com
# connected to url /1420/ with host xkcd.com
# connected to url /249/ with host xkcd.com
# connected to url /1419/ with host xkcd.com
# connected to url /250/ with host xkcd.com
# connected to url /251/ with host xkcd.com
# connected to url /1418/ with host xkcd.com
# connected to url /252/ with host xkcd.com
# connected to url /1417/ with host xkcd.com
# connected to url /253/ with host xkcd.com
# connected to url /1416/ with host xkcd.com
# connected to url /254/ with host xkcd.com
# connected to url /1415/ with host xkcd.com
# connected to url /255/ with host xkcd.com
# connected to url /1414/ with host xkcd.com
# connected to url /256/ with host xkcd.com
# connected to url /1413/ with host xkcd.com
# connected to url /257/ with host xkcd.com
# connected to url /1412/ with host xkcd.com
# connected to url /258/ with host xkcd.com
# connected to url /1411/ with host xkcd.com
# connected to url /1410/ with host xkcd.com
# connected to url /259/ with host xkcd.com
# connected to url /1409/ with host xkcd.com
# connected to url /260/ with host xkcd.com
# connected to url /1408/ with host xkcd.com
# connected to url /261/ with host xkcd.com
# connected to url /1407/ with host xkcd.com
# connected to url /262/ with host xkcd.com
# connected to url /263/ with host xkcd.com
# connected to url /1406/ with host xkcd.com
# connected to url /264/ with host xkcd.com
# connected to url /1405/ with host xkcd.com
# connected to url /265/ with host xkcd.com
# connected to url /1404/ with host xkcd.com
# connected to url /266/ with host xkcd.com
# connected to url /1403/ with host xkcd.com
# connected to url /267/ with host xkcd.com
# connected to url /268/ with host xkcd.com
# connected to url /1402/ with host xkcd.com
# connected to url /269/ with host xkcd.com
# connected to url /1401/ with host xkcd.com
# connected to url /1400/ with host xkcd.com
# connected to url /270/ with host xkcd.com
# connected to url /1399/ with host xkcd.com
# connected to url /1398/ with host xkcd.com
# connected to url /271/ with host xkcd.com
# connected to url /1397/ with host xkcd.com
# connected to url /272/ with host xkcd.com
# connected to url /273/ with host xkcd.com
# connected to url /1396/ with host xkcd.com
# connected to url /274/ with host xkcd.com
# connected to url /1395/ with host xkcd.com
# connected to url /1394/ with host xkcd.com
# connected to url /275/ with host xkcd.com
# connected to url /1393/ with host xkcd.com
# connected to url /276/ with host xkcd.com
# connected to url /1392/ with host xkcd.com
# connected to url /277/ with host xkcd.com
# connected to url /1391/ with host xkcd.com
# connected to url /278/ with host xkcd.com
# connected to url /1390/ with host xkcd.com
# connected to url /279/ with host xkcd.com
# connected to url /1389/ with host xkcd.com
# connected to url /280/ with host xkcd.com
# connected to url /1388/ with host xkcd.com
# connected to url /1387/ with host xkcd.com
# connected to url /281/ with host xkcd.com
# connected to url /1386/ with host xkcd.com
# connected to url /282/ with host xkcd.com
# connected to url /1385/ with host xkcd.com
# connected to url /283/ with host xkcd.com
# connected to url /1384/ with host xkcd.com
# connected to url /1383/ with host xkcd.com
# connected to url /284/ with host xkcd.com
# connected to url /1382/ with host xkcd.com
# connected to url /285/ with host xkcd.com
# connected to url /1381/ with host xkcd.com
# connected to url /286/ with host xkcd.com
# connected to url /1380/ with host xkcd.com
# connected to url /287/ with host xkcd.com
# connected to url /288/ with host xkcd.com
# connected to url /1379/ with host xkcd.com
# connected to url /289/ with host xkcd.com
# connected to url /1378/ with host xkcd.com
# connected to url /290/ with host xkcd.com
# connected to url /1377/ with host xkcd.com
# connected to url /1376/ with host xkcd.com
# connected to url /291/ with host xkcd.com
# connected to url /1375/ with host xkcd.com
# connected to url /292/ with host xkcd.com
# connected to url /1374/ with host xkcd.com
# connected to url /293/ with host xkcd.com
# connected to url /294/ with host xkcd.com
# connected to url /1373/ with host xkcd.com
# connected to url /295/ with host xkcd.com
# connected to url /1372/ with host xkcd.com
# connected to url /1371/ with host xkcd.com
# connected to url /296/ with host xkcd.com
# connected to url /1370/ with host xkcd.com
# connected to url /297/ with host xkcd.com
# connected to url /1369/ with host xkcd.com
# connected to url /298/ with host xkcd.com
# connected to url /1368/ with host xkcd.com
# connected to url /299/ with host xkcd.com
# connected to url /1367/ with host xkcd.com
# connected to url /300/ with host xkcd.com
# connected to url /1366/ with host xkcd.com
# connected to url /301/ with host xkcd.com
# connected to url /1365/ with host xkcd.com
# connected to url /302/ with host xkcd.com
# connected to url /1364/ with host xkcd.com
# connected to url /303/ with host xkcd.com
# connected to url /1363/ with host xkcd.com
# connected to url /304/ with host xkcd.com
# connected to url /1362/ with host xkcd.com
# connected to url /1361/ with host xkcd.com
# connected to url /305/ with host xkcd.com
# connected to url /1360/ with host xkcd.com
# connected to url /306/ with host xkcd.com
# connected to url /1359/ with host xkcd.com
# connected to url /307/ with host xkcd.com
# connected to url /1358/ with host xkcd.com
# connected to url /308/ with host xkcd.com
# connected to url /1357/ with host xkcd.com
# connected to url /1356/ with host xkcd.com
# connected to url /309/ with host xkcd.com
# connected to url /1355/ with host xkcd.com
# connected to url /310/ with host xkcd.com
# connected to url /311/ with host xkcd.com
# connected to url /1354/ with host xkcd.com
# connected to url /1353/ with host xkcd.com
# connected to url /312/ with host xkcd.com
# connected to url /1352/ with host xkcd.com
# connected to url /313/ with host xkcd.com
# connected to url /1351/ with host xkcd.com
# connected to url /314/ with host xkcd.com
# connected to url /1350/ with host xkcd.com
# connected to url /315/ with host xkcd.com
# connected to url /1349/ with host xkcd.com
# connected to url /316/ with host xkcd.com
# connected to url /1348/ with host xkcd.com
# connected to url /317/ with host xkcd.com
# connected to url /1347/ with host xkcd.com
# connected to url /318/ with host xkcd.com
# connected to url /1346/ with host xkcd.com
# connected to url /319/ with host xkcd.com
# connected to url /320/ with host xkcd.com
# connected to url /1345/ with host xkcd.com
# connected to url /1344/ with host xkcd.com
# connected to url /321/ with host xkcd.com
# connected to url /1343/ with host xkcd.com
# connected to url /322/ with host xkcd.com
# connected to url /323/ with host xkcd.com
# connected to url /1342/ with host xkcd.com
# connected to url /324/ with host xkcd.com
# connected to url /1341/ with host xkcd.com
# connected to url /325/ with host xkcd.com
# connected to url /326/ with host xkcd.com
# connected to url /1340/ with host xkcd.com
# connected to url /327/ with host xkcd.com
# connected to url /1339/ with host xkcd.com
# connected to url /1338/ with host xkcd.com
# connected to url /328/ with host xkcd.com
# connected to url /1337/ with host xkcd.com
# connected to url /329/ with host xkcd.com
# connected to url /1336/ with host xkcd.com
# connected to url /330/ with host xkcd.com
# connected to url /1335/ with host xkcd.com
# connected to url /331/ with host xkcd.com
# connected to url /1334/ with host xkcd.com
# connected to url /332/ with host xkcd.com
# connected to url /1333/ with host xkcd.com
# connected to url /333/ with host xkcd.com
# connected to url /1332/ with host xkcd.com
# connected to url /334/ with host xkcd.com
# connected to url /1331/ with host xkcd.com
# connected to url /335/ with host xkcd.com
# connected to url /1330/ with host xkcd.com
# connected to url /1329/ with host xkcd.com
# connected to url /336/ with host xkcd.com
# connected to url /1328/ with host xkcd.com
# connected to url /337/ with host xkcd.com
# connected to url /1327/ with host xkcd.com
# connected to url /338/ with host xkcd.com
# connected to url /1326/ with host xkcd.com
# connected to url /339/ with host xkcd.com
# connected to url /1325/ with host xkcd.com
# connected to url /340/ with host xkcd.com
# connected to url /1324/ with host xkcd.com
# connected to url /341/ with host xkcd.com
# connected to url /1323/ with host xkcd.com
# connected to url /342/ with host xkcd.com
# connected to url /1322/ with host xkcd.com
# connected to url /343/ with host xkcd.com
# connected to url /1321/ with host xkcd.com
# connected to url /344/ with host xkcd.com
# connected to url /1320/ with host xkcd.com
# connected to url /345/ with host xkcd.com
# connected to url /1319/ with host xkcd.com
# connected to url /346/ with host xkcd.com
# connected to url /347/ with host xkcd.com
# connected to url /1318/ with host xkcd.com
# connected to url /348/ with host xkcd.com
# connected to url /1317/ with host xkcd.com
# connected to url /349/ with host xkcd.com
# connected to url /1316/ with host xkcd.com
# connected to url /350/ with host xkcd.com
# connected to url /1315/ with host xkcd.com
# connected to url /351/ with host xkcd.com
# connected to url /1314/ with host xkcd.com
# connected to url /352/ with host xkcd.com
# connected to url /353/ with host xkcd.com
# connected to url /1313/ with host xkcd.com
# connected to url /354/ with host xkcd.com
# connected to url /1312/ with host xkcd.com
# connected to url /1311/ with host xkcd.com
# connected to url /355/ with host xkcd.com
# connected to url /1310/ with host xkcd.com
# connected to url /356/ with host xkcd.com
# connected to url /1309/ with host xkcd.com
# connected to url /357/ with host xkcd.com
# connected to url /358/ with host xkcd.com
# connected to url /1308/ with host xkcd.com
# connected to url /359/ with host xkcd.com
# connected to url /1307/ with host xkcd.com
# connected to url /360/ with host xkcd.com
# connected to url /1306/ with host xkcd.com
# connected to url /1305/ with host xkcd.com
# connected to url /361/ with host xkcd.com
# connected to url /1304/ with host xkcd.com
# connected to url /362/ with host xkcd.com
# connected to url /1303/ with host xkcd.com
# connected to url /363/ with host xkcd.com
# connected to url /1302/ with host xkcd.com
# connected to url /364/ with host xkcd.com
# connected to url /1301/ with host xkcd.com
# connected to url /365/ with host xkcd.com
# connected to url /1300/ with host xkcd.com
# connected to url /366/ with host xkcd.com
# connected to url /1299/ with host xkcd.com
# connected to url /1298/ with host xkcd.com
# connected to url /367/ with host xkcd.com
# connected to url /1297/ with host xkcd.com
# connected to url /368/ with host xkcd.com
# connected to url /1296/ with host xkcd.com
# connected to url /369/ with host xkcd.com
# connected to url /1295/ with host xkcd.com
# connected to url /370/ with host xkcd.com
# connected to url /1294/ with host xkcd.com
# connected to url /371/ with host xkcd.com
# connected to url /1293/ with host xkcd.com
# connected to url /1292/ with host xkcd.com
# connected to url /372/ with host xkcd.com
# connected to url /1291/ with host xkcd.com
# connected to url /373/ with host xkcd.com
# connected to url /374/ with host xkcd.com
# connected to url /1290/ with host xkcd.com
# connected to url /375/ with host xkcd.com
# connected to url /376/ with host xkcd.com
# connected to url /1289/ with host xkcd.com
# connected to url /377/ with host xkcd.com
# connected to url /1288/ with host xkcd.com
# connected to url /378/ with host xkcd.com
# connected to url /1287/ with host xkcd.com
# connected to url /379/ with host xkcd.com
# connected to url /1286/ with host xkcd.com
# connected to url /380/ with host xkcd.com
# connected to url /1285/ with host xkcd.com
# connected to url /381/ with host xkcd.com
# connected to url /1284/ with host xkcd.com
# connected to url /382/ with host xkcd.com
# connected to url /1283/ with host xkcd.com
# connected to url /383/ with host xkcd.com
# connected to url /384/ with host xkcd.com
# connected to url /1282/ with host xkcd.com
# connected to url /385/ with host xkcd.com
# connected to url /1281/ with host xkcd.com
# connected to url /386/ with host xkcd.com
# connected to url /1280/ with host xkcd.com
# connected to url /387/ with host xkcd.com
# connected to url /1279/ with host xkcd.com
# connected to url /388/ with host xkcd.com
# connected to url /1278/ with host xkcd.com
# connected to url /389/ with host xkcd.com
# connected to url /1277/ with host xkcd.com
# connected to url /390/ with host xkcd.com
# connected to url /1276/ with host xkcd.com
# connected to url /391/ with host xkcd.com
# connected to url /1275/ with host xkcd.com
# connected to url /392/ with host xkcd.com
# connected to url /1274/ with host xkcd.com
# connected to url /393/ with host xkcd.com
# connected to url /394/ with host xkcd.com
# connected to url /1273/ with host xkcd.com
# connected to url /395/ with host xkcd.com
# connected to url /1272/ with host xkcd.com
# connected to url /1271/ with host xkcd.com
# connected to url /396/ with host xkcd.com
# connected to url /397/ with host xkcd.com
# connected to url /1270/ with host xkcd.com
# connected to url /1269/ with host xkcd.com
# connected to url /398/ with host xkcd.com
# connected to url /399/ with host xkcd.com
# connected to url /1268/ with host xkcd.com
# connected to url /400/ with host xkcd.com
# connected to url /1267/ with host xkcd.com
# connected to url /401/ with host xkcd.com
# connected to url /1266/ with host xkcd.com
# connected to url /1265/ with host xkcd.com
# connected to url /402/ with host xkcd.com
# connected to url /1264/ with host xkcd.com
# connected to url /403/ with host xkcd.com
# connected to url /1263/ with host xkcd.com
# connected to url /405/ with host xkcd.com
# connected to url /1262/ with host xkcd.com
# connected to url /406/ with host xkcd.com
# connected to url /1261/ with host xkcd.com
# connected to url /407/ with host xkcd.com
# connected to url /1260/ with host xkcd.com
# connected to url /408/ with host xkcd.com
# connected to url /1259/ with host xkcd.com
# connected to url /409/ with host xkcd.com
# connected to url /1258/ with host xkcd.com
# connected to url /410/ with host xkcd.com
# connected to url /1257/ with host xkcd.com
# connected to url /411/ with host xkcd.com
# connected to url /1256/ with host xkcd.com
# connected to url /412/ with host xkcd.com
# connected to url /1255/ with host xkcd.com
# connected to url /413/ with host xkcd.com
# connected to url /1254/ with host xkcd.com
# connected to url /414/ with host xkcd.com
# connected to url /1253/ with host xkcd.com
# connected to url /415/ with host xkcd.com
# connected to url /416/ with host xkcd.com
# connected to url /1252/ with host xkcd.com
# connected to url /417/ with host xkcd.com
# connected to url /1251/ with host xkcd.com
# connected to url /418/ with host xkcd.com
# connected to url /1250/ with host xkcd.com
# connected to url /419/ with host xkcd.com
# connected to url /1249/ with host xkcd.com
# connected to url /1248/ with host xkcd.com
# connected to url /420/ with host xkcd.com
# connected to url /1247/ with host xkcd.com
# connected to url /421/ with host xkcd.com
# connected to url /1246/ with host xkcd.com
# connected to url /422/ with host xkcd.com
# connected to url /1245/ with host xkcd.com
# connected to url /423/ with host xkcd.com
# connected to url /1244/ with host xkcd.com
# connected to url /424/ with host xkcd.com
# connected to url /1243/ with host xkcd.com
# connected to url /425/ with host xkcd.com
# connected to url /1242/ with host xkcd.com
# connected to url /426/ with host xkcd.com
# connected to url /1241/ with host xkcd.com
# connected to url /427/ with host xkcd.com
# connected to url /428/ with host xkcd.com
# connected to url /1240/ with host xkcd.com
# connected to url /429/ with host xkcd.com
# connected to url /1239/ with host xkcd.com
# connected to url /430/ with host xkcd.com
# connected to url /1238/ with host xkcd.com
# connected to url /1237/ with host xkcd.com
# connected to url /431/ with host xkcd.com
# connected to url /432/ with host xkcd.com
# connected to url /1236/ with host xkcd.com
# connected to url /433/ with host xkcd.com
# connected to url /1235/ with host xkcd.com
# connected to url /434/ with host xkcd.com
# connected to url /1234/ with host xkcd.com
# connected to url /435/ with host xkcd.com
# connected to url /1233/ with host xkcd.com
# connected to url /436/ with host xkcd.com
# connected to url /437/ with host xkcd.com
# connected to url /1232/ with host xkcd.com
# connected to url /1231/ with host xkcd.com
# connected to url /438/ with host xkcd.com
# connected to url /1230/ with host xkcd.com
# connected to url /439/ with host xkcd.com
# connected to url /1229/ with host xkcd.com
# connected to url /440/ with host xkcd.com
# connected to url /1228/ with host xkcd.com
# connected to url /441/ with host xkcd.com
# connected to url /1227/ with host xkcd.com
# connected to url /442/ with host xkcd.com
# connected to url /1226/ with host xkcd.com
# connected to url /443/ with host xkcd.com
# connected to url /1225/ with host xkcd.com
# connected to url /444/ with host xkcd.com
# connected to url /445/ with host xkcd.com
# connected to url /1224/ with host xkcd.com
# connected to url /1223/ with host xkcd.com
# connected to url /446/ with host xkcd.com
# connected to url /1222/ with host xkcd.com
# connected to url /447/ with host xkcd.com
# connected to url /448/ with host xkcd.com
# connected to url /1221/ with host xkcd.com
# connected to url /449/ with host xkcd.com
# connected to url /1220/ with host xkcd.com
# connected to url /450/ with host xkcd.com
# connected to url /1219/ with host xkcd.com
# connected to url /1218/ with host xkcd.com
# connected to url /451/ with host xkcd.com
# connected to url /1217/ with host xkcd.com
# connected to url /452/ with host xkcd.com
# connected to url /1216/ with host xkcd.com
# connected to url /453/ with host xkcd.com
# connected to url /1215/ with host xkcd.com
# connected to url /454/ with host xkcd.com
# connected to url /1214/ with host xkcd.com
# connected to url /455/ with host xkcd.com
# connected to url /1213/ with host xkcd.com
# connected to url /456/ with host xkcd.com
# connected to url /1212/ with host xkcd.com
# connected to url /457/ with host xkcd.com
# connected to url /458/ with host xkcd.com
# connected to url /1211/ with host xkcd.com
# connected to url /459/ with host xkcd.com
# connected to url /1210/ with host xkcd.com
# connected to url /460/ with host xkcd.com
# connected to url /1209/ with host xkcd.com
# connected to url /461/ with host xkcd.com
# connected to url /1208/ with host xkcd.com
# connected to url /462/ with host xkcd.com
# connected to url /1207/ with host xkcd.com
# connected to url /463/ with host xkcd.com
# connected to url /1206/ with host xkcd.com
# connected to url /464/ with host xkcd.com
# connected to url /1205/ with host xkcd.com
# connected to url /465/ with host xkcd.com
# connected to url /1204/ with host xkcd.com
# connected to url /466/ with host xkcd.com
# connected to url /467/ with host xkcd.com
# connected to url /1203/ with host xkcd.com
# connected to url /468/ with host xkcd.com
# connected to url /1202/ with host xkcd.com
# connected to url /469/ with host xkcd.com
# connected to url /1201/ with host xkcd.com
# connected to url /470/ with host xkcd.com
# connected to url /1200/ with host xkcd.com
# connected to url /471/ with host xkcd.com
# connected to url /1199/ with host xkcd.com
# connected to url /472/ with host xkcd.com
# connected to url /1198/ with host xkcd.com
# connected to url /473/ with host xkcd.com
# connected to url /1197/ with host xkcd.com
# connected to url /474/ with host xkcd.com
# connected to url /1196/ with host xkcd.com
# connected to url /475/ with host xkcd.com
# connected to url /476/ with host xkcd.com
# connected to url /1195/ with host xkcd.com
# connected to url /477/ with host xkcd.com
# connected to url /1194/ with host xkcd.com
# connected to url /478/ with host xkcd.com
# connected to url /1193/ with host xkcd.com
# connected to url /479/ with host xkcd.com
# connected to url /1192/ with host xkcd.com
# connected to url /480/ with host xkcd.com
# connected to url /1191/ with host xkcd.com
# connected to url /481/ with host xkcd.com
# connected to url /1190/ with host xkcd.com
# connected to url /1189/ with host xkcd.com
# connected to url /482/ with host xkcd.com
# connected to url /1188/ with host xkcd.com
# connected to url /483/ with host xkcd.com
# connected to url /1187/ with host xkcd.com
# connected to url /484/ with host xkcd.com
# connected to url /1186/ with host xkcd.com
# connected to url /485/ with host xkcd.com
# connected to url /1185/ with host xkcd.com
# connected to url /486/ with host xkcd.com
# connected to url /1184/ with host xkcd.com
# connected to url /487/ with host xkcd.com
# connected to url /1183/ with host xkcd.com
# connected to url /488/ with host xkcd.com
# connected to url /1182/ with host xkcd.com
# connected to url /489/ with host xkcd.com
# connected to url /1181/ with host xkcd.com
# connected to url /490/ with host xkcd.com
# connected to url /1180/ with host xkcd.com
# connected to url /491/ with host xkcd.com
# connected to url /1179/ with host xkcd.com
# connected to url /492/ with host xkcd.com
# connected to url /1178/ with host xkcd.com
# connected to url /493/ with host xkcd.com
# connected to url /1177/ with host xkcd.com
# connected to url /494/ with host xkcd.com
# connected to url /1176/ with host xkcd.com
# connected to url /495/ with host xkcd.com
# connected to url /1175/ with host xkcd.com
# connected to url /496/ with host xkcd.com
# connected to url /1174/ with host xkcd.com
# connected to url /497/ with host xkcd.com
# connected to url /1173/ with host xkcd.com
# connected to url /498/ with host xkcd.com
# connected to url /1172/ with host xkcd.com
# connected to url /499/ with host xkcd.com
# connected to url /1171/ with host xkcd.com
# connected to url /500/ with host xkcd.com
# connected to url /1170/ with host xkcd.com
# connected to url /1169/ with host xkcd.com
# connected to url /501/ with host xkcd.com
# connected to url /1168/ with host xkcd.com
# connected to url /1167/ with host xkcd.com
# connected to url /502/ with host xkcd.com
# connected to url /503/ with host xkcd.com
# connected to url /1166/ with host xkcd.com
# connected to url /504/ with host xkcd.com
# connected to url /1165/ with host xkcd.com
# connected to url /505/ with host xkcd.com
# connected to url /1164/ with host xkcd.com
# connected to url /506/ with host xkcd.com
# connected to url /1163/ with host xkcd.com
# connected to url /507/ with host xkcd.com
# connected to url /1162/ with host xkcd.com
# connected to url /508/ with host xkcd.com
# connected to url /1161/ with host xkcd.com
# connected to url /509/ with host xkcd.com
# connected to url /1160/ with host xkcd.com
# connected to url /510/ with host xkcd.com
# connected to url /1159/ with host xkcd.com
# connected to url /511/ with host xkcd.com
# connected to url /1158/ with host xkcd.com
# connected to url /512/ with host xkcd.com
# connected to url /1157/ with host xkcd.com
# connected to url /513/ with host xkcd.com
# connected to url /1156/ with host xkcd.com
# connected to url /514/ with host xkcd.com
# connected to url /1155/ with host xkcd.com
# connected to url /515/ with host xkcd.com
# connected to url /1154/ with host xkcd.com
# connected to url /516/ with host xkcd.com
# connected to url /1153/ with host xkcd.com
# connected to url /517/ with host xkcd.com
# connected to url /1152/ with host xkcd.com
# connected to url /518/ with host xkcd.com
# connected to url /1151/ with host xkcd.com
# connected to url /519/ with host xkcd.com
# connected to url /520/ with host xkcd.com
# connected to url /1150/ with host xkcd.com
# connected to url /1149/ with host xkcd.com
# connected to url /521/ with host xkcd.com
# connected to url /522/ with host xkcd.com
# connected to url /1148/ with host xkcd.com
# connected to url /1147/ with host xkcd.com
# connected to url /523/ with host xkcd.com
# connected to url /1146/ with host xkcd.com
# connected to url /524/ with host xkcd.com
# connected to url /1145/ with host xkcd.com
# connected to url /525/ with host xkcd.com
# connected to url /1144/ with host xkcd.com
# connected to url /526/ with host xkcd.com
# connected to url /1143/ with host xkcd.com
# connected to url /527/ with host xkcd.com
# connected to url /1142/ with host xkcd.com
# connected to url /528/ with host xkcd.com
# connected to url /1141/ with host xkcd.com
# connected to url /529/ with host xkcd.com
# connected to url /1140/ with host xkcd.com
# connected to url /530/ with host xkcd.com
# connected to url /1139/ with host xkcd.com
# connected to url /531/ with host xkcd.com
# connected to url /1138/ with host xkcd.com
# connected to url /532/ with host xkcd.com
# connected to url /1137/ with host xkcd.com
# connected to url /533/ with host xkcd.com
# connected to url /1136/ with host xkcd.com
# connected to url /534/ with host xkcd.com
# connected to url /535/ with host xkcd.com
# connected to url /1135/ with host xkcd.com
# connected to url /536/ with host xkcd.com
# connected to url /1134/ with host xkcd.com
# connected to url /537/ with host xkcd.com
# connected to url /538/ with host xkcd.com
# connected to url /1133/ with host xkcd.com
# connected to url /539/ with host xkcd.com
# connected to url /1132/ with host xkcd.com
# connected to url /540/ with host xkcd.com
# connected to url /541/ with host xkcd.com
# connected to url /1131/ with host xkcd.com
# connected to url /1130/ with host xkcd.com
# connected to url /542/ with host xkcd.com
# connected to url /1129/ with host xkcd.com
# connected to url /543/ with host xkcd.com
# connected to url /1128/ with host xkcd.com
# connected to url /544/ with host xkcd.com
# connected to url /1127/ with host xkcd.com
# connected to url /545/ with host xkcd.com
# connected to url /1126/ with host xkcd.com
# connected to url /546/ with host xkcd.com
# connected to url /1125/ with host xkcd.com
# connected to url /547/ with host xkcd.com
# connected to url /548/ with host xkcd.com
# connected to url /1124/ with host xkcd.com
# connected to url /549/ with host xkcd.com
# connected to url /1123/ with host xkcd.com
# connected to url /550/ with host xkcd.com
# connected to url /1122/ with host xkcd.com
# connected to url /551/ with host xkcd.com
# connected to url /552/ with host xkcd.com
# connected to url /1121/ with host xkcd.com
# connected to url /553/ with host xkcd.com
# connected to url /1120/ with host xkcd.com
# connected to url /554/ with host xkcd.com
# connected to url /1119/ with host xkcd.com
# connected to url /555/ with host xkcd.com
# connected to url /556/ with host xkcd.com
# connected to url /1118/ with host xkcd.com
# connected to url /557/ with host xkcd.com
# connected to url /1117/ with host xkcd.com
# connected to url /558/ with host xkcd.com
# connected to url /1116/ with host xkcd.com
# connected to url /559/ with host xkcd.com
# connected to url /1115/ with host xkcd.com
# connected to url /560/ with host xkcd.com
# connected to url /1114/ with host xkcd.com
# connected to url /561/ with host xkcd.com
# connected to url /1113/ with host xkcd.com
# connected to url /562/ with host xkcd.com
# connected to url /1112/ with host xkcd.com
# connected to url /563/ with host xkcd.com
# connected to url /1111/ with host xkcd.com
# connected to url /564/ with host xkcd.com
# connected to url /1110/ with host xkcd.com
# connected to url /565/ with host xkcd.com
# connected to url /1109/ with host xkcd.com
# connected to url /566/ with host xkcd.com
# connected to url /1108/ with host xkcd.com
# connected to url /567/ with host xkcd.com
# connected to url /1107/ with host xkcd.com
# connected to url /568/ with host xkcd.com
# ...
# connected to url /1028/ with host xkcd.com
# connected to url /649/ with host xkcd.com
# connected to url /1027/ with host xkcd.com
# connected to url /650/ with host xkcd.com
# connected to url /1026/ with host xkcd.com
# connected to url /651/ with host xkcd.com
# connected to url /1025/ with host xkcd.com
# connected to url /652/ with host xkcd.com
# connected to url /1024/ with host xkcd.com
# connected to url /653/ with host xkcd.com
# connected to url /1023/ with host xkcd.com
# connected to url /654/ with host xkcd.com
# connected to url /1022/ with host xkcd.com
# connected to url /655/ with host xkcd.com
# connected to url /1021/ with host xkcd.com
# connected to url /656/ with host xkcd.com
# connected to url /1020/ with host xkcd.com
# connected to url /1019/ with host xkcd.com
# connected to url /657/ with host xkcd.com
# connected to url /658/ with host xkcd.com
# connected to url /1018/ with host xkcd.com
# connected to url /659/ with host xkcd.com
# connected to url /1017/ with host xkcd.com
# connected to url /660/ with host xkcd.com
# connected to url /1016/ with host xkcd.com
# connected to url /661/ with host xkcd.com
# connected to url /1015/ with host xkcd.com
# connected to url /662/ with host xkcd.com
# connected to url /1014/ with host xkcd.com
# connected to url /663/ with host xkcd.com
# connected to url /664/ with host xkcd.com
# connected to url /1013/ with host xkcd.com
# connected to url /665/ with host xkcd.com
# connected to url /1012/ with host xkcd.com
# connected to url /666/ with host xkcd.com
# connected to url /1011/ with host xkcd.com
# connected to url /667/ with host xkcd.com
# connected to url /1010/ with host xkcd.com
# connected to url /668/ with host xkcd.com
# connected to url /1009/ with host xkcd.com
# connected to url /669/ with host xkcd.com
# connected to url /1008/ with host xkcd.com
# connected to url /670/ with host xkcd.com
# connected to url /1007/ with host xkcd.com
# connected to url /671/ with host xkcd.com
# connected to url /1006/ with host xkcd.com
# connected to url /1005/ with host xkcd.com
# connected to url /672/ with host xkcd.com
# connected to url /1004/ with host xkcd.com
# connected to url /673/ with host xkcd.com
# connected to url /1003/ with host xkcd.com
# connected to url /674/ with host xkcd.com
# connected to url /1002/ with host xkcd.com
# connected to url /675/ with host xkcd.com
# connected to url /1001/ with host xkcd.com
# connected to url /1000/ with host xkcd.com
# connected to url /676/ with host xkcd.com
# connected to url /999/ with host xkcd.com
# connected to url /677/ with host xkcd.com
# connected to url /678/ with host xkcd.com
# connected to url /998/ with host xkcd.com
# connected to url /997/ with host xkcd.com
# connected to url /679/ with host xkcd.com
# connected to url /996/ with host xkcd.com
# connected to url /680/ with host xkcd.com
# connected to url /995/ with host xkcd.com
# connected to url /681/ with host xkcd.com
# connected to url /994/ with host xkcd.com
# connected to url /682/ with host xkcd.com
# connected to url /993/ with host xkcd.com
# connected to url /683/ with host xkcd.com
# connected to url /992/ with host xkcd.com
# connected to url /684/ with host xkcd.com
# connected to url /991/ with host xkcd.com
# connected to url /685/ with host xkcd.com
# connected to url /990/ with host xkcd.com
# connected to url /686/ with host xkcd.com
# connected to url /989/ with host xkcd.com
# connected to url /687/ with host xkcd.com
# connected to url /988/ with host xkcd.com
# connected to url /688/ with host xkcd.com
# connected to url /987/ with host xkcd.com
# connected to url /689/ with host xkcd.com
# connected to url /986/ with host xkcd.com
# connected to url /690/ with host xkcd.com
# connected to url /985/ with host xkcd.com
# connected to url /691/ with host xkcd.com
# connected to url /984/ with host xkcd.com
# connected to url /692/ with host xkcd.com
# connected to url /983/ with host xkcd.com
# connected to url /693/ with host xkcd.com
# connected to url /982/ with host xkcd.com
# connected to url /694/ with host xkcd.com
# connected to url /695/ with host xkcd.com
# connected to url /981/ with host xkcd.com
# connected to url /696/ with host xkcd.com
# connected to url /980/ with host xkcd.com
# connected to url /697/ with host xkcd.com
# connected to url /979/ with host xkcd.com
# connected to url /698/ with host xkcd.com
# connected to url /978/ with host xkcd.com
# connected to url /699/ with host xkcd.com
# connected to url /700/ with host xkcd.com
# connected to url /977/ with host xkcd.com
# connected to url /701/ with host xkcd.com
# connected to url /976/ with host xkcd.com
# connected to url /702/ with host xkcd.com
# connected to url /975/ with host xkcd.com
# connected to url /703/ with host xkcd.com
# connected to url /704/ with host xkcd.com
# connected to url /974/ with host xkcd.com
# connected to url /973/ with host xkcd.com
# connected to url /705/ with host xkcd.com
# connected to url /706/ with host xkcd.com
# connected to url /972/ with host xkcd.com
# connected to url /707/ with host xkcd.com
# connected to url /971/ with host xkcd.com
# connected to url /708/ with host xkcd.com
# connected to url /970/ with host xkcd.com
# connected to url /709/ with host xkcd.com
# connected to url /710/ with host xkcd.com
# connected to url /969/ with host xkcd.com
# connected to url /711/ with host xkcd.com
# connected to url /968/ with host xkcd.com
# connected to url /967/ with host xkcd.com
# connected to url /712/ with host xkcd.com
# connected to url /966/ with host xkcd.com
# connected to url /713/ with host xkcd.com
# connected to url /965/ with host xkcd.com
# connected to url /964/ with host xkcd.com
# connected to url /714/ with host xkcd.com
# connected to url /963/ with host xkcd.com
# connected to url /715/ with host xkcd.com
# connected to url /962/ with host xkcd.com
# connected to url /716/ with host xkcd.com
# connected to url /961/ with host xkcd.com
# connected to url /717/ with host xkcd.com
# connected to url /960/ with host xkcd.com
# connected to url /718/ with host xkcd.com
# connected to url /959/ with host xkcd.com
# connected to url /719/ with host xkcd.com
# connected to url /958/ with host xkcd.com
# connected to url /720/ with host xkcd.com
# connected to url /957/ with host xkcd.com
# connected to url /721/ with host xkcd.com
# connected to url /956/ with host xkcd.com
# connected to url /722/ with host xkcd.com
# connected to url /955/ with host xkcd.com
# connected to url /723/ with host xkcd.com
# connected to url /954/ with host xkcd.com
# connected to url /953/ with host xkcd.com
# connected to url /724/ with host xkcd.com
# connected to url /952/ with host xkcd.com
# connected to url /725/ with host xkcd.com
# connected to url /951/ with host xkcd.com
# connected to url /726/ with host xkcd.com
# connected to url /950/ with host xkcd.com
# connected to url /727/ with host xkcd.com
# connected to url /728/ with host xkcd.com
# connected to url /949/ with host xkcd.com
# connected to url /729/ with host xkcd.com
# connected to url /948/ with host xkcd.com
# connected to url /730/ with host xkcd.com
# connected to url /947/ with host xkcd.com
# connected to url /946/ with host xkcd.com
# connected to url /731/ with host xkcd.com
# connected to url /945/ with host xkcd.com
# connected to url /944/ with host xkcd.com
# connected to url /732/ with host xkcd.com
# connected to url /943/ with host xkcd.com
# connected to url /733/ with host xkcd.com
# connected to url /734/ with host xkcd.com
# connected to url /942/ with host xkcd.com
# connected to url /941/ with host xkcd.com
# connected to url /735/ with host xkcd.com
# connected to url /940/ with host xkcd.com
# connected to url /736/ with host xkcd.com
# connected to url /939/ with host xkcd.com
# connected to url /737/ with host xkcd.com
# connected to url /938/ with host xkcd.com
# connected to url /738/ with host xkcd.com
# connected to url /739/ with host xkcd.com
# connected to url /937/ with host xkcd.com
# connected to url /740/ with host xkcd.com
# connected to url /936/ with host xkcd.com
# connected to url /741/ with host xkcd.com
# connected to url /935/ with host xkcd.com
# connected to url /742/ with host xkcd.com
# connected to url /934/ with host xkcd.com
# connected to url /743/ with host xkcd.com
# connected to url /933/ with host xkcd.com
# connected to url /744/ with host xkcd.com
# connected to url /932/ with host xkcd.com
# connected to url /931/ with host xkcd.com
# connected to url /745/ with host xkcd.com
# connected to url /930/ with host xkcd.com
# connected to url /746/ with host xkcd.com
# connected to url /929/ with host xkcd.com
# connected to url /747/ with host xkcd.com
# connected to url /748/ with host xkcd.com
# connected to url /928/ with host xkcd.com
# connected to url /749/ with host xkcd.com
# connected to url /927/ with host xkcd.com
# connected to url /750/ with host xkcd.com
# connected to url /926/ with host xkcd.com
# connected to url /751/ with host xkcd.com
# connected to url /925/ with host xkcd.com
# connected to url /752/ with host xkcd.com
# connected to url /924/ with host xkcd.com
# connected to url /753/ with host xkcd.com
# connected to url /923/ with host xkcd.com
# connected to url /754/ with host xkcd.com
# connected to url /922/ with host xkcd.com
# connected to url /921/ with host xkcd.com
# connected to url /755/ with host xkcd.com
# connected to url /920/ with host xkcd.com
# connected to url /756/ with host xkcd.com
# connected to url /757/ with host xkcd.com
# connected to url /919/ with host xkcd.com
# connected to url /918/ with host xkcd.com
# connected to url /758/ with host xkcd.com
# connected to url /917/ with host xkcd.com
# connected to url /759/ with host xkcd.com
# connected to url /916/ with host xkcd.com
# connected to url /760/ with host xkcd.com
# connected to url /915/ with host xkcd.com
# connected to url /761/ with host xkcd.com
# connected to url /914/ with host xkcd.com
# connected to url /762/ with host xkcd.com
# connected to url /913/ with host xkcd.com
# connected to url /763/ with host xkcd.com
# connected to url /912/ with host xkcd.com
# connected to url /764/ with host xkcd.com
# connected to url /911/ with host xkcd.com
# connected to url /910/ with host xkcd.com
# connected to url /765/ with host xkcd.com
# connected to url /909/ with host xkcd.com
# connected to url /766/ with host xkcd.com
# connected to url /767/ with host xkcd.com
# connected to url /908/ with host xkcd.com
# connected to url /768/ with host xkcd.com
# connected to url /907/ with host xkcd.com
# connected to url /769/ with host xkcd.com
# connected to url /906/ with host xkcd.com
# connected to url /770/ with host xkcd.com
# connected to url /905/ with host xkcd.com
# connected to url /771/ with host xkcd.com
# connected to url /904/ with host xkcd.com
# connected to url /903/ with host xkcd.com
# connected to url /772/ with host xkcd.com
# connected to url /902/ with host xkcd.com
# connected to url /773/ with host xkcd.com
# connected to url /901/ with host xkcd.com
# connected to url /774/ with host xkcd.com
# connected to url /900/ with host xkcd.com
# connected to url /775/ with host xkcd.com
# connected to url /899/ with host xkcd.com
# connected to url /776/ with host xkcd.com
# connected to url /898/ with host xkcd.com
# connected to url /777/ with host xkcd.com
# connected to url /897/ with host xkcd.com
# connected to url /778/ with host xkcd.com
# connected to url /896/ with host xkcd.com
# connected to url /779/ with host xkcd.com
# connected to url /895/ with host xkcd.com
# connected to url /780/ with host xkcd.com
# connected to url /894/ with host xkcd.com
# connected to url /781/ with host xkcd.com
# connected to url /782/ with host xkcd.com
# connected to url /893/ with host xkcd.com
# connected to url /892/ with host xkcd.com
# connected to url /783/ with host xkcd.com
# connected to url /891/ with host xkcd.com
# connected to url /784/ with host xkcd.com
# connected to url /890/ with host xkcd.com
# connected to url /785/ with host xkcd.com
# connected to url /889/ with host xkcd.com
# connected to url /786/ with host xkcd.com
# connected to url /888/ with host xkcd.com
# connected to url /787/ with host xkcd.com
# connected to url /887/ with host xkcd.com
# connected to url /788/ with host xkcd.com
# connected to url /886/ with host xkcd.com
# connected to url /789/ with host xkcd.com
# connected to url /790/ with host xkcd.com
# connected to url /885/ with host xkcd.com
# connected to url /884/ with host xkcd.com
# connected to url /791/ with host xkcd.com
# connected to url /792/ with host xkcd.com
# connected to url /883/ with host xkcd.com
# connected to url /793/ with host xkcd.com
# connected to url /882/ with host xkcd.com
# connected to url /794/ with host xkcd.com
# connected to url /881/ with host xkcd.com
# connected to url /795/ with host xkcd.com
# connected to url /880/ with host xkcd.com
# connected to url /796/ with host xkcd.com
# connected to url /879/ with host xkcd.com
# connected to url /797/ with host xkcd.com
# connected to url /878/ with host xkcd.com
# connected to url /798/ with host xkcd.com
# connected to url /877/ with host xkcd.com
# connected to url /799/ with host xkcd.com
# connected to url /800/ with host xkcd.com
# connected to url /876/ with host xkcd.com
# connected to url /801/ with host xkcd.com
# connected to url /875/ with host xkcd.com
# connected to url /802/ with host xkcd.com
# connected to url /874/ with host xkcd.com
# connected to url /803/ with host xkcd.com
# connected to url /873/ with host xkcd.com
# connected to url /804/ with host xkcd.com
# connected to url /872/ with host xkcd.com
# connected to url /805/ with host xkcd.com
# connected to url /871/ with host xkcd.com
# connected to url /806/ with host xkcd.com
# connected to url /870/ with host xkcd.com
# connected to url /807/ with host xkcd.com
# connected to url /869/ with host xkcd.com
# connected to url /808/ with host xkcd.com
# connected to url /868/ with host xkcd.com
# connected to url /809/ with host xkcd.com
# connected to url /867/ with host xkcd.com
# connected to url /810/ with host xkcd.com
# connected to url /866/ with host xkcd.com
# connected to url /811/ with host xkcd.com
# connected to url /812/ with host xkcd.com
# connected to url /865/ with host xkcd.com
# connected to url /813/ with host xkcd.com
# connected to url /864/ with host xkcd.com
# connected to url /863/ with host xkcd.com
# connected to url /814/ with host xkcd.com
# connected to url /815/ with host xkcd.com
# connected to url /862/ with host xkcd.com
# connected to url /816/ with host xkcd.com
# connected to url /861/ with host xkcd.com
# connected to url /817/ with host xkcd.com
# connected to url /860/ with host xkcd.com
# connected to url /818/ with host xkcd.com
# connected to url /859/ with host xkcd.com
# connected to url /819/ with host xkcd.com
# connected to url /858/ with host xkcd.com
# connected to url /820/ with host xkcd.com
# connected to url /857/ with host xkcd.com
# connected to url /821/ with host xkcd.com
# connected to url /856/ with host xkcd.com
# connected to url /822/ with host xkcd.com
# connected to url /855/ with host xkcd.com
# connected to url /823/ with host xkcd.com
# connected to url /854/ with host xkcd.com
# connected to url /824/ with host xkcd.com
# connected to url /825/ with host xkcd.com
# connected to url /853/ with host xkcd.com
# connected to url /826/ with host xkcd.com
# connected to url /852/ with host xkcd.com
# connected to url /851/ with host xkcd.com
# connected to url /827/ with host xkcd.com
# connected to url /850/ with host xkcd.com
# connected to url /828/ with host xkcd.com
# connected to url /849/ with host xkcd.com
# connected to url /829/ with host xkcd.com
# connected to url /848/ with host xkcd.com
# connected to url /830/ with host xkcd.com
# connected to url /847/ with host xkcd.com
# connected to url /831/ with host xkcd.com
# connected to url /846/ with host xkcd.com
# connected to url /832/ with host xkcd.com
# connected to url /845/ with host xkcd.com
# connected to url /833/ with host xkcd.com
# connected to url /844/ with host xkcd.com
# connected to url /834/ with host xkcd.com
# connected to url /843/ with host xkcd.com
# connected to url /835/ with host xkcd.com
# connected to url /842/ with host xkcd.com
# connected to url /836/ with host xkcd.com
# connected to url /841/ with host xkcd.com
# connected to url /837/ with host xkcd.com
# connected to url /840/ with host xkcd.com
# connected to url /838/ with host xkcd.com
# connected to url /839/ with host xkcd.com
